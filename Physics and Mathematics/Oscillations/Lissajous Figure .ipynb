# %%
#So,today we are starting to plot the lissajous figure of different parametric equations.
#The parametric equations are X=Asin(nt+d) and Y=Bcos(mt+e)
#to plot the graph we need to import matplotlib

import matplotlib.pyplot as plt
import numpy as np
import seaboen as sns 

t0 = 0 #setting initial value of parameter t
t1 = 10 #setting the final value of parameter t
A = 1 #the value of the constant
B = 1 #the value of the constant
pi = np.pi #the value of the constant
n = 4 #the value of the constant
m = 2 #the value of the constant
d = 0 #the value of the constant
e = pi/7 #the value of the constant

# now we have to create an array of varriable "t" which will store the value of t in small increments
step = 0.01 # setting the value of step .This will increament t
t = np.arange(t0, t1, step)

#lets create the x and y variables to store the values, x and y will be arrays
size=len(t)
x=np.empty(size)
y=np.empty(size)

#now we will start the actual calculation
i=0
while(i<size):
    x[i]=A*np.sin(n*t[i]+d)
    y[i]=B*np.sin(m*t[i]+e)
    i=i+1
plt.figure(figsize=(7,4))
plt.plot(x,y, color="r", linewidth= 1)
plt.title("$\delta=0  \quad \omega_x=4 \quad \omega_y=2$")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.grid(True)
plt.show()

#now lets run the code...........

# %%
#So,today we are starting to plot the lissajous figure of different parametric equations.
#The parametric equations are X=Asin(nt+d) and Y=Bcos(mt+e)
#to plot the graph we need to import matplotlib

import matplotlib.pyplot as plt
import numpy as np

t0 = 0 #setting initial value of parameter t
t1 = 10 #setting the final value of parameter t
A = 1 #the value of the constant
B = 1 #the value of the constant
pi = np.pi #the value of the constant
#n = 1 #the value of the constant
#m = 4 #the value of the constant
d = 0 #the value of the constant
e = pi/4 #the value of the constant

# now we have to create an array of varriable "t" which will store the value of t in small increments
step = 0.01 # setting the value of step .This will increament t
t = np.arange(t0, t1, step)

#lets create the x and y variables to store the values, x and y will be arrays
size=len(t)
x=np.empty(size)
y=np.empty(size)

x1=np.empty(size)
y1=np.empty(size)

#now we will start the actual calculation
i=0
while(i<size):
    x[i]=A*np.sin(1*t[i])
    y[i]=B*np.sin(2*t[i]+np.pi/4)
    i=i+1

i=0
while(i<size):
    x1[i]=A*np.sin(1*t[i]+0)
    y1[i]=B*np.sin(2*t[i]+0)
    i=i+1
    
    
plt.figure(figsize=(7,4))
plt.plot(x,y, color="r", linewidth= 1, label="$\omega_x=1, \quad \omega_y=2, \quad \delta=\pi/4$")
plt.plot(x1,y1, color="b", linewidth= 1, label="$\omega_x=1, \quad \omega_y=2, \quad \delta=0$")
#plt.title("$\delta=\pi /4  \quad \omega_x=1 \quad \omega_y=4$")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.legend()
plt.grid(True)
plt.show()

#now lets run the code...........
